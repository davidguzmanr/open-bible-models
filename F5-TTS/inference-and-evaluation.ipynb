# %% [markdown]
# # Ewe-Igbo-Yoruba (Yoruba New Testament only)

# %%
# %%bash
# python inference-test-split.py \
#     --language Yoruba \
#     --ckpt_path ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba-nt/model_last.pt \
#     --vocab_file data/open-bible-ewe-igbo-yoruba-nt_custom/vocab.txt \
#     --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Ewe-Igbo-Yoruba-Nt.yaml \
#     --metadata_path data/open-bible-ewe-igbo-yoruba-nt/metadata.csv

# %%
import os
import pandas as pd
import IPython.display as ipd
from pathlib import Path

ref_index = 0

CKPT_PATH = "ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba-nt/model_last.pt"
OUTPUT_DIR = f"synthesis_output/{Path(CKPT_PATH).parent.name}"

test = pd.read_csv(os.path.join(OUTPUT_DIR, "test.csv"))

row = test.iloc[ref_index]
stem = os.path.splitext(row["filename"])[0]
transcript = row["text"]

gen_path = os.path.join(OUTPUT_DIR, "generated", f"{stem}.wav")
gt_path  = os.path.join(OUTPUT_DIR, "ground-truth", f"{stem}.wav")

ipd.display(ipd.Markdown(f"**Transcript:** {transcript}"))
ipd.display(ipd.Markdown("**Generated audio:**"))
ipd.display(ipd.Audio(gen_path))
ipd.display(ipd.Markdown("**Ground-truth audio:**"))
ipd.display(ipd.Audio(gt_path))

# %% [markdown]
# # Yoruba New Testament only

# %%
# %%bash
# python inference-test-split.py \
#     --language Yoruba \
#     --ckpt_path ckpts/F5TTS_v1_Base_vocos_custom_open-bible-yoruba-nt/model_last.pt \
#     --vocab_file data/open-bible-yoruba-nt_custom/vocab.txt \
#     --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Yoruba-Nt.yaml \
#     --metadata_path data/open-bible-yoruba-nt/metadata.csv

# %%
import os
import pandas as pd
import IPython.display as ipd
from pathlib import Path

ref_index = 0

CKPT_PATH = "ckpts/F5TTS_v1_Base_vocos_custom_open-bible-yoruba-nt/model_last.pt"
OUTPUT_DIR = f"synthesis_output/{Path(CKPT_PATH).parent.name}"

test = pd.read_csv(os.path.join(OUTPUT_DIR, "test.csv"))

row = test.iloc[ref_index]
stem = os.path.splitext(row["filename"])[0]
transcript = row["text"]

gen_path = os.path.join(OUTPUT_DIR, "generated", f"{stem}.wav")
gt_path  = os.path.join(OUTPUT_DIR, "ground-truth", f"{stem}.wav")

ipd.display(ipd.Markdown(f"**Transcript:** {transcript}"))
ipd.display(ipd.Markdown("**Generated audio:**"))
ipd.display(ipd.Audio(gen_path))
ipd.display(ipd.Markdown("**Ground-truth audio:**"))
ipd.display(ipd.Audio(gt_path))

# %% [markdown]
# # Ewe-Igbo-Yoruba (Yoruba New Testament only + fine-tuning)

# %%
# This worked
# %%bash
python inference-test-split.py \
    --language Yoruba \
    --ckpt_path ckpts/open-bible-yoruba-nt-finetune/model_last.pt \
    --vocab_file data/open-bible-ewe-igbo-yoruba-nt_custom/vocab.txt \
    --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Ewe-Igbo-Yoruba-Nt.yaml \
    --metadata_path data/open-bible-ewe-igbo-yoruba-nt/metadata.csv

# %%
import os
import pandas as pd
import IPython.display as ipd
from pathlib import Path

ref_index = 0

CKPT_PATH = "ckpts/open-bible-yoruba-nt-finetune/model_last.pt"
OUTPUT_DIR = f"synthesis_output/{Path(CKPT_PATH).parent.name}"

test = pd.read_csv(os.path.join(OUTPUT_DIR, "test.csv"))

row = test.iloc[ref_index]
stem = os.path.splitext(row["filename"])[0]
transcript = row["text"]

gen_path = os.path.join(OUTPUT_DIR, "generated", f"{stem}.wav")
gt_path  = os.path.join(OUTPUT_DIR, "ground-truth", f"{stem}.wav")

ipd.display(ipd.Markdown(f"**Transcript:** {transcript}"))
ipd.display(ipd.Markdown("**Generated audio:**"))
ipd.display(ipd.Audio(gen_path))
ipd.display(ipd.Markdown("**Ground-truth audio:**"))
ipd.display(ipd.Audio(gt_path))

# %% [markdown]
# # Ewe-Igbo-Yoruba (full data)

# %%
# %%bash
# python inference-test-split.py \
#     --language Yoruba \
#     --ckpt_path ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba/model_last.pt \
#     --vocab_file data/open-bible-ewe-igbo-yoruba_custom/vocab.txt \
#     --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Ewe-Igbo-Yoruba.yaml \
#     --metadata_path data/open-bible-ewe-igbo-yoruba/metadata.csv

# %%
import os
import pandas as pd
import IPython.display as ipd
from pathlib import Path

ref_index = 0

CKPT_PATH = "ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba/model_last.pt"
OUTPUT_DIR = f"synthesis_output/{Path(CKPT_PATH).parent.name}"

test = pd.read_csv(os.path.join(OUTPUT_DIR, "test.csv"))

row = test.iloc[ref_index]
stem = os.path.splitext(row["filename"])[0]
transcript = row["text"]

gen_path = os.path.join(OUTPUT_DIR, "generated", f"{stem}.wav")
gt_path  = os.path.join(OUTPUT_DIR, "ground-truth", f"{stem}.wav")

ipd.display(ipd.Markdown(f"**Transcript:** {transcript}"))
ipd.display(ipd.Markdown("**Generated audio:**"))
ipd.display(ipd.Audio(gen_path))
ipd.display(ipd.Markdown("**Ground-truth audio:**"))
ipd.display(ipd.Audio(gt_path))
# Out:
# **Transcript:** Bí ó ṣe ń bá mi sọ̀rọ̀, mo ti sùn lọ fọnfọn, bí mo ṣe da ojú bolẹ̀. Nígbà náà ni ó fi ọwọ́ kàn mí, ó sì gbé mi dúró lórí ẹsẹ̀ mi.
# **Generated audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **Ground-truth audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Ewe-Igbo-Yoruba-Tagged (Yoruba New Testament only)

# %%
# %%bash
# python inference-test-split-tagged.py \
#    --language Yoruba \
#    --ckpt_path ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba-nt-tagged/model_last.pt \
#    --vocab_file data/open-bible-ewe-igbo-yoruba-nt-tagged_custom/vocab.txt \
#    --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Ewe-Igbo-Yoruba-Nt-Tagged.yaml \
#    --metadata_path data/open-bible-yoruba-nt/metadata.csv

# %%
python inference-test-split-tagged.py \
   --language Yoruba \
   --ckpt_path ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba-nt-tagged/model_last.pt \
   --vocab_file data/open-bible-ewe-igbo-yoruba-nt-tagged_custom/vocab.txt \
   --model_cfg src/f5_tts/configs/F5TTS_v1_Base_Open_Bible_Ewe-Igbo-Yoruba-Nt-Tagged.yaml \
   --metadata_path data/open-bible-yoruba-nt/metadata.csv \
   --prepend

# %%
import os
import pandas as pd
import IPython.display as ipd
from pathlib import Path

ref_index = 0

CKPT_PATH = "ckpts/F5TTS_v1_Base_vocos_custom_open-bible-ewe-igbo-yoruba-nt-tagged/model_last.pt"
LANGUAGE   = "Yoruba"
OUTPUT_DIR = os.path.join("synthesis_output", Path(CKPT_PATH).parent.name, LANGUAGE)

test = pd.read_csv(os.path.join(OUTPUT_DIR, "test.csv"))

row = test.iloc[ref_index]
stem = os.path.splitext(row["filename"])[0]
transcript = row["text"]

gen_path = os.path.join(OUTPUT_DIR, "generated", f"{stem}.wav")
gt_path  = os.path.join(OUTPUT_DIR, "ground-truth", f"{stem}.wav")

ipd.display(ipd.Markdown(f"**Transcript:** {transcript}"))
ipd.display(ipd.Markdown("**Generated audio:**"))
ipd.display(ipd.Audio(gen_path))
ipd.display(ipd.Markdown("**Ground-truth audio:**"))
ipd.display(ipd.Audio(gt_path))
# Out:
# **Transcript:** Bí ó ṣe ń bá mi sọ̀rọ̀, mo ti sùn lọ fọnfọn, bí mo ṣe da ojú bolẹ̀. Nígbà náà ni ó fi ọwọ́ kàn mí, ó sì gbé mi dúró lórí ẹsẹ̀ mi.
# **Generated audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **Ground-truth audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
